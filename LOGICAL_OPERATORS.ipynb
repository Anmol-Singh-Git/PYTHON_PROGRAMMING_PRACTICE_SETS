# %% [markdown]
# <a href="https://colab.research.google.com/github/Anmol-Singh-Git/PYTHON_PROGRAMMING_PRACTICE_SETS/blob/main/LOGICAL_OPERATORS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROGRAMS ON EVEN AND ODD NUMBERS

# %%
# PROGRAM TO COUNT AND PRINT EVEN AND ODD NUMBERS FROM A RANGE

# e=0
# o=0
# for i in range(1,11):
#   if i%2==0:
#     e+=1
#     print(i)
#   else:
#     o+=1
#     print(i)
# print(e)
# print(o)
# print(i)


# PROGRAM TO COUNT AND PRINT EVEN AND ODD NUMBERS FROM USER'S RANGE SEPARATING EVEN & ODD

# e=0
# o=0
# even=''
# odd=''
# a=int(input('Enter the initial range: '))
# b=int(input('Enter the final range: '))
# for i in range(a,b):
#   if i%2==0:
#     e+=1
#     even+=str(i)+","
#   else:
#     o+=1
#     odd+=str(i)+','
# print(f'Count of even numbers are : {e}')
# print(f'Count of odd numbers are : {o}')
# print(f'Total even and odd numbers are : {e+o}')
# print(f'Even numbers are : {even}')
# print(f'Odd numbers are : {odd}')


# PROGRAM TO COUNT AND PRINT EVEN AND ODD NUMBERS FROM USER'S RANGE ALONG WITH EVEN AND ODD NUMBERS SUM

# e=0
# o=0
# even=''
# odd=''
# j=0
# k=0
# a=int(input('Enter the initial range: '))
# b=int(input('Enter the final range: '))
# for i in range(a,b):
#   if i%2==0:
#     e+=1
#     j+=i
#     even+=str(i)+","
#   else:
#     o+=1
#     k+=i
#     odd+=str(i)+','
# print('\n'+f'Count of even numbers are : {e}'+'\n')
# print(f'Count of odd numbers are : {o}'+'\n')
# print(f'Total even and odd numbers are : {e+o}'+'\n')
# print(f'Even numbers are : {even}'+'\n')
# print(f'Odd numbers are : {odd}','\n')
# print(f'Sum of even numbers are : {j}'+'\n')
# print(f'Sum of odd numbers are : {k}'+'\n')
# print(f'Sum of even and odd numbers are : {j+k}')
# Out:
# Enter the initial range: 2
# Enter the final range: 5
#
# Count of even numbers are : 2
#
# Count of odd numbers are : 1
#
# Total even and odd numbers are : 3
#
# Even numbers are : 2,4,
#
# Odd numbers are : 3,
#
# Sum of even numbers are : 6
#
# Sum of odd numbers are : 3
#
# Sum of even and odd numbers are : 9

# %% [markdown]
# # PROGRAMS

# %%
a='#'
b='@'
c=4
print(a+c*b)
# Out:
# #@@@@

# %%
products = {
    "Laptop": 10,
    "Mouse": 3,
    "keyboard": 0,
    'monitor':7,
    'printer':2
}


for name , stocks in products.items():
  if(stocks==0):
    print(name,":out of stock")
  elif(stocks<=5):
    print(name,":Low")
  else:
    print(name,":Available")
# Out:
# Laptop :Available
# Mouse :Low
# keyboard :out of stock
# monitor :Available
# printer :Low
